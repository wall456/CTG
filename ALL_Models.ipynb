# %% [markdown]
# <a href="https://colab.research.google.com/github/wall456/CTG/blob/main/ALL_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
raw_data = pd.read_csv("CTG.csv")
raw_data = raw_data.iloc[:-3]
cleaned_data = raw_data.drop(columns=['LBE', 'SegFile', 'FileName', 'Date', 'DR', 'b', 'e', 'A', 'B', 'C', 'D', 'E', 'AD', 'DE', 'LD', 'FS', 'SUSP', 'CLASS', 'NSP'])
X = cleaned_data
y = raw_data['NSP']
n, d = X.shape


holdout_frac = 0.2
holdout_splitter = StratifiedShuffleSplit(n_splits=1, test_size=holdout_frac, random_state=42)
model_idx, holdout_idx = next(holdout_splitter.split(X, y))
X_m, y_m = X.loc[model_idx], y.loc[model_idx]
X_h, y_h = X.loc[holdout_idx], y.loc[holdout_idx]

# %%
from sklearn.pipeline import Pipeline 
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
pipe1 = Pipeline([('scale', StandardScaler()),
                 ('dim_reduce', PCA()),
                 ('classify'  , KNeighborsClassifier())
                 ])
hyperparams1 = {'dim_reduce__n_components' : np.arange(1, d+1),
               'classify__n_neighbors' : np.arange(1, 11),
               'classify__weights' : ['uniform', 'distance'],
               'classify__p' : np.arange(1, 6)
               }
grid1 = GridSearchCV(pipe1, hyperparams1, cv=10, scoring='f1_macro').fit(X_m, y_m)

results1 = grid1.cv_results_
df1 = pd.DataFrame(results1['params'])
df1['score'] = results1['mean_test_score']
M1 = df1['score'].max()
mask1 = df1['score'] >= M1 * 0.95
df1[mask1].sort_values(by='score', ascending=False)
# Out:
#       classify__n_neighbors  classify__p classify__weights  \
# 662                       4            1          distance
# 664                       4            1          distance
# 663                       4            1          distance
# 1084                      6            1          distance
# 1083                      6            1          distance
# ...                     ...          ...               ...
# 769                       4            4           uniform
# 348                       2            4           uniform
# 349                       2            4           uniform
# 645                       4            1           uniform
# 1066                      6            1           uniform
#
#       dim_reduce__n_components     score
# 662                         12  0.857422
# 664                         14  0.853038
# 663                         13  0.851158
# 1084                        14  0.850854
# 1083                        13  0.850526
# ...                        ...       ...
# 769                         14  0.814757
# 348                         13  0.814747
# 349                         14  0.814747
# 645                         16  0.814632
# 1066                        17  0.814620
#
# [1103 rows x 5 columns]

# %%
pipe2 = Pipeline([('scale', MinMaxScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', KNeighborsClassifier()),
                 ])
hyperparams2 = {'dim_reduce__n_components': np.arange(1, d+1),
               'classify__n_neighbors': np.arange(1, 11),
               'classify__weights': ['uniform', 'distance'],
               'classify__p': np.arange(1,6)
               }
grid2 = GridSearchCV(pipe2, hyperparams2, cv=10, scoring='f1_macro').fit(X_m, y_m)

results2 = grid2.cv_results_
df2 = pd.DataFrame(results2['params'])
df2['score'] = results2['mean_test_score']
M2 = df2['score'].max()
mask2 = df2['score'] >= M2 * 0.95
df2[mask2].sort_values(by='score', ascending=False)
# Out:
#       classify__n_neighbors  classify__p classify__weights  \
# 712                       4            2          distance
# 711                       4            2          distance
# 713                       4            2          distance
# 710                       4            2          distance
# 709                       4            2          distance
# ...                     ...          ...               ...
# 364                       2            4          distance
# 133                       1            4           uniform
# 154                       1            4          distance
# 890                       5            2           uniform
# 1068                      6            1           uniform
#
#       dim_reduce__n_components     score
# 712                         20  0.852068
# 711                         19  0.852068
# 713                         21  0.852068
# 710                         18  0.851882
# 709                         17  0.851073
# ...                        ...       ...
# 364                          8  0.809633
# 133                          8  0.809633
# 154                          8  0.809633
# 890                          9  0.809612
# 1068                        19  0.809506
#
# [1179 rows x 5 columns]

# %%
pipe3 = Pipeline([('scale', RobustScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', KNeighborsClassifier())
                 ])
hyperparams3 = {'dim_reduce__n_components': np.arange(1, d+1),
               'classify__n_neighbors': np.arange(1, 11),
               'classify__weights': ['uniform', 'distance'],
               'classify__p': np.arange(1,6)
               }
grid3 = GridSearchCV(pipe3, hyperparams3, cv=10, scoring='f1_macro').fit(X_m, y_m)

results3 = grid3.cv_results_
df3 = pd.DataFrame(results3['params'])
df3['score'] = results3['mean_test_score']
M3 = df3['score'].max()
mask3 = df3['score'] >= M3 * 0.95
df3[mask3].sort_values(by='score', ascending=False)
# Out:
#       classify__n_neighbors  classify__p classify__weights  \
# 876                       5            1          distance
# 666                       4            1          distance
# 668                       4            1          distance
# 458                       3            1          distance
# 667                       4            1          distance
# ...                     ...          ...               ...
# 326                       2            3          distance
# 116                       1            3          distance
# 642                       4            1           uniform
# 558                       3            4           uniform
# 1755                      9            2          distance
#
#       dim_reduce__n_components     score
# 876                         16  0.852448
# 666                         16  0.851236
# 668                         18  0.850321
# 458                         18  0.850020
# 667                         17  0.849627
# ...                        ...       ...
# 326                         12  0.810059
# 116                         12  0.810059
# 642                         13  0.810049
# 558                         13  0.809959
# 1755                        13  0.809936
#
# [476 rows x 5 columns]

# %%
pipe4 = Pipeline([('scale', StandardScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', GaussianNB())
                 ])
hyperparams4 = {'dim_reduce__n_components': np.arange(1, d+1),
              }
grid4 = GridSearchCV(pipe4, hyperparams4, cv=10, scoring='f1_macro').fit(X_m, y_m)

results4 = grid4.cv_results_
df4 = pd.DataFrame(results4['params'])
df4['score'] = results4['mean_test_score']
M4 = df4['score'].max()
mask4 = df4['score'] >= M4 * 0.95
df4[mask4].sort_values(by='score', ascending=False)
# Out:
#     dim_reduce__n_components     score
# 3                          4  0.759535
# 4                          5  0.749736
# 6                          7  0.740804
# 5                          6  0.735842
# 9                         10  0.734726
# 7                          8  0.731560
# 11                        12  0.729698
# 10                        11  0.729212
# 8                          9  0.729147
# 2                          3  0.727695
# 12                        13  0.725365

# %%
pipe5 = Pipeline([('scale', MinMaxScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', GaussianNB())
                 ])
hyperparams5 = {'dim_reduce__n_components': np.arange(1, d+1),
               }
grid5 = GridSearchCV(pipe5, hyperparams5, cv=10, scoring='f1_macro').fit(X_m, y_m)

results5 = grid5.cv_results_
df5 = pd.DataFrame(results5['params'])
df5['score'] = results5['mean_test_score']
M5 = df5['score'].max()
mask5 = df5['score'] >= M5 * 0.95
df5[mask5].sort_values(by='score', ascending=False)
# Out:
#     dim_reduce__n_components     score
# 8                          9  0.747123
# 7                          8  0.746602
# 10                        11  0.743803
# 9                         10  0.743361
# 11                        12  0.736351
# 12                        13  0.733714
# 6                          7  0.733501
# 13                        14  0.719451

# %%
pipe6 = Pipeline([('scale', RobustScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', GaussianNB())
                 ])
hyperparams6 = {'dim_reduce__n_components': np.arange(1, d+1),
               }
grid6 = GridSearchCV(pipe6, hyperparams6, cv=10, scoring='f1_macro').fit(X_m, y_m)

results6 = grid6.cv_results_
df6 = pd.DataFrame(results6['params'])
df6['score'] = results6['mean_test_score']
M6 = df6['score'].max()
mask6 = df6['score'] >= M6 * 0.95
df6[mask6].sort_values(by='score', ascending=False)
# Out:
#     dim_reduce__n_components     score
# 12                        13  0.731232
# 14                        15  0.729974
# 13                        14  0.728527
# 11                        12  0.724014
# 10                        11  0.723625
# 9                         10  0.719501
# 16                        17  0.717862
# 15                        16  0.716146
# 8                          9  0.712386
# 17                        18  0.709503
# 7                          8  0.707674
# 6                          7  0.707604
# 18                        19  0.706337
# 4                          5  0.705217
# 2                          3  0.703106
# 3                          4  0.702825
# 5                          6  0.700518

# %%
pipe7 = Pipeline([('scale', StandardScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', DecisionTreeClassifier())
                 ])
hyperparams7 = {'dim_reduce__n_components': np.arange(1, d+1),
               'classify__criterion': ['gini', 'entropy'],
               'classify__max_depth': np.arange(1, d+1)
               }
grid7 = GridSearchCV(pipe7, hyperparams7, cv=10, scoring='f1_macro').fit(X_m, y_m)

results7 = grid7.cv_results_
df7 = pd.DataFrame(results7['params'])
df7['score'] = results7['mean_test_score']
M7 = df7['score'].max()
mask7 = df7['score'] >= M7 * 0.95
df7[mask7].sort_values(by='score', ascending=False)
# Out:
#     classify__criterion  classify__max_depth  dim_reduce__n_components  \
# 837             entropy                   19                        19
# 752             entropy                   15                        18
# 710             entropy                   13                        18
# 606             entropy                    8                        19
# 857             entropy                   20                        18
# ..                  ...                  ...                       ...
# 88                 gini                    5                         5
# 389                gini                   19                        12
# 760             entropy                   16                         5
# 550             entropy                    6                         5
# 743             entropy                   15                         9
#
#         score
# 837  0.802396
# 752  0.800152
# 710  0.799974
# 606  0.799381
# 857  0.799369
# ..        ...
# 88   0.762339
# 389  0.762336
# 760  0.762325
# 550  0.762290
# 743  0.762289
#
# [435 rows x 4 columns]

# %%
pipe8 = Pipeline([('scale', MinMaxScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', DecisionTreeClassifier())
                 ])
hyperparams8 = {'dim_reduce__n_components': np.arange(1, d+1),
               'classify__criterion': ['gini', 'entropy'],
               'classify__max_depth': (1, d+1)
               }
grid8 = GridSearchCV(pipe8, hyperparams8, cv=10, scoring='f1_macro').fit(X_m, y_m)

results8 = grid8.cv_results_
df8 = pd.DataFrame(results8['params'])
df8['score'] = results8['mean_test_score']
M8 = df8['score'].max()
mask8 = df8['score'] >= M8 * 0.95
df8[mask8].sort_values(by='score', ascending=False)
# Out:
#    classify__criterion  classify__max_depth  dim_reduce__n_components  \
# 70             entropy                   22                         8
# 79             entropy                   22                        17
# 71             entropy                   22                         9
# 78             entropy                   22                        16
# 76             entropy                   22                        14
# 75             entropy                   22                        13
# 80             entropy                   22                        18
# 77             entropy                   22                        15
# 81             entropy                   22                        19
# 82             entropy                   22                        20
# 83             entropy                   22                        21
# 69             entropy                   22                         7
# 72             entropy                   22                        10
# 73             entropy                   22                        11
# 37                gini                   22                        17
# 35                gini                   22                        15
# 27                gini                   22                         7
# 74             entropy                   22                        12
# 36                gini                   22                        16
# 28                gini                   22                         8
# 33                gini                   22                        13
# 34                gini                   22                        14
# 32                gini                   22                        12
# 26                gini                   22                         6
# 41                gini                   22                        21
# 68             entropy                   22                         6
#
#        score
# 70  0.801432
# 79  0.801396
# 71  0.798538
# 78  0.797248
# 76  0.795773
# 75  0.794744
# 80  0.794332
# 77  0.793923
# 81  0.793728
# 82  0.790575
# 83  0.789540
# 69  0.784362
# 72  0.782209
# 73  0.781327
# 37  0.777141
# 35  0.772373
# 27  0.770735
# 74  0.770318
# 36  0.767951
# 28  0.767271
# 33  0.767106
# 34  0.766767
# 32  0.766543
# 26  0.764453
# 41  0.762967
# 68  0.761539

# %%
pipe9 = Pipeline([('scale', RobustScaler()),
                 ('dim_reduce', PCA()),
                 ('classify', DecisionTreeClassifier())
                 ])
hyperparams9 = {'dim_reduce__n_components': np.arange(1, d+1),
               'classify__criterion': ['gini', 'entropy'],
               'classify__max_depth': np.arange(1, d+1)
               }
grid9 = GridSearchCV(pipe9, hyperparams9, cv=10, scoring='f1_macro').fit(X_m, y_m)

results9 = grid9.cv_results_
df9 = pd.DataFrame(results9['params'])
df9['score'] = results9['mean_test_score']
M9 = df9['score'].max()
mask9 = df9['score'] >= M9 * 0.95
df9[mask9].sort_values(by='score', ascending=False)
# Out:
#     classify__criterion  classify__max_depth  dim_reduce__n_components  \
# 878             entropy                   21                        18
# 667             entropy                   11                        17
# 665             entropy                   11                        15
# 836             entropy                   19                        18
# 748             entropy                   15                        14
# ..                  ...                  ...                       ...
# 177                gini                    9                        10
# 394                gini                   19                        17
# 619             entropy                    9                        11
# 573             entropy                    7                         7
# 629             entropy                    9                        21
#
#         score
# 878  0.816229
# 667  0.814773
# 665  0.812248
# 836  0.811687
# 748  0.810777
# ..        ...
# 177  0.775962
# 394  0.775939
# 619  0.775813
# 573  0.775762
# 629  0.775607
#
# [186 rows x 4 columns]

# %%
pipe10 = Pipeline([('scale', StandardScaler()),
                  ('dim_reduce', PCA()),
                  ('classify', RandomForestClassifier())
                  ])
hyperparams10 = {'dim_reduce__n_components': np.arange(1, d+1),
                'classify__criterion': ['gini', 'entropy'],
                'classify__max_depth': np.arange(1, 10),
                'classify__min_samples_split': np.arange(2, 4)
                }
grid10 = GridSearchCV(pipe10, hyperparams10, cv=10, scoring='f1_macro').fit(X_m, y_m)

results10 = grid10.cv_results_
df10 = pd.DataFrame(results10['params'])
df10['score'] = results10['mean_test_score']
M10 = df10['score'].max()
mask10 = df10['score'] >= M10 * 0.95
df10[mask10].sort_values(by='score', ascending=False)
# Out:
#     classify__criterion  classify__max_depth  classify__min_samples_split  \
# 683             entropy                    8                            2
# 731             entropy                    9                            2
# 684             entropy                    8                            2
# 726             entropy                    9                            2
# 722             entropy                    9                            2
# ..                  ...                  ...                          ...
# 612             entropy                    6                            3
# 285                gini                    7                            3
# 625             entropy                    6                            3
# 291                gini                    7                            3
# 617             entropy                    6                            3
#
#      dim_reduce__n_components     score
# 683                        12  0.830076
# 731                        18  0.828497
# 684                        13  0.828461
# 726                        13  0.827928
# 722                         9  0.827850
# ..                        ...       ...
# 612                         4  0.789925
# 285                        13  0.789611
# 625                        17  0.789526
# 291                        19  0.789079
# 617                         9  0.789036
#
# [222 rows x 5 columns]

# %%
pipe11 = Pipeline([('scale', MinMaxScaler()),
                  ('dim_reduce', PCA()),
                  ('classify', RandomForestClassifier())
                  ])
hyperparams11 = {'dim_reduce__n_components': np.arange(1, d+1),
                'classify__criterion': ['gini', 'entropy'],
                'classify__max_depth': np.arange(1, 10),
                'classify__min_samples_split': np.arange(2, 4)
                }
grid11 = GridSearchCV(pipe11, hyperparams11, cv=10, scoring='f1_macro').fit(X_m, y_m)

# %%
results11 = grid11.cv_results_
df11 = pd.DataFrame(results11['params'])
df11['score'] = results11['mean_test_score']
M11 = df11['score'].max()
mask11 = df11['score'] >= M11 * 0.95
df11[mask11].sort_values(by='score', ascending=False)
# Out:
#     classify__criterion  classify__max_depth  classify__min_samples_split  \
# 743             entropy                    9                            3
# 722             entropy                    9                            2
# 730             entropy                    9                            2
# 342                gini                    9                            2
# 751             entropy                    9                            3
# ..                  ...                  ...                          ...
# 335                gini                    8                            3
# 650             entropy                    7                            2
# 624             entropy                    6                            3
# 237                gini                    6                            3
# 286                gini                    7                            3
#
#      dim_reduce__n_components     score
# 743                         9  0.839355
# 722                         9  0.838500
# 730                        17  0.836073
# 342                         7  0.835137
# 751                        17  0.833839
# ..                        ...       ...
# 335                        21  0.798684
# 650                        21  0.798527
# 624                        16  0.798484
# 237                         7  0.798080
# 286                        14  0.797473
#
# [213 rows x 5 columns]

# %%
pipe12 = Pipeline([('scale', RobustScaler()),
                  ('dim_reduce', PCA()),
                  ('classify', RandomForestClassifier())
                  ])
hyperparams12 = {'dim_reduce__n_components': np.arange(1, d+1),
                'classify__criterion': ['gini', 'entropy'],
                'classify__max_depth': np.arange(1, 10),
                'classify__min_samples_split': np.arange(2, 4)
                }
grid12 = GridSearchCV(pipe12, hyperparams12, cv=10, scoring='f1_macro').fit(X_m, y_m)

# %%
results12 = grid12.cv_results_
df12 = pd.DataFrame(results12['params'])
df12['score'] = results12['mean_test_score']
M12 = df12['score'].max()
mask12 = df12['score'] >= M12 * 0.95
df12[mask12].sort_values(by='score', ascending=False)
# Out:
#     classify__criterion  classify__max_depth  classify__min_samples_split  \
# 727             entropy                    9                            2
# 728             entropy                    9                            2
# 724             entropy                    9                            2
# 708             entropy                    8                            3
# 730             entropy                    9                            2
# ..                  ...                  ...                          ...
# 262                gini                    7                            2
# 636             entropy                    7                            2
# 340                gini                    9                            2
# 223                gini                    6                            2
# 698             entropy                    8                            3
#
#      dim_reduce__n_components     score
# 727                        14  0.842002
# 728                        15  0.840037
# 724                        11  0.839759
# 708                        16  0.838961
# 730                        17  0.837806
# ..                        ...       ...
# 262                        11  0.800976
# 636                         7  0.800708
# 340                         5  0.800245
# 223                        14  0.800185
# 698                         6  0.800103
#
# [199 rows x 5 columns]

# %%
pipe13 = Pipeline([('scale', StandardScaler()),
                  ('dim_reduce', PCA()),
                  ('classify', SVC())
                  ])
hyperparams13 = {'dim_reduce__n_components': np.arange(1, d+1),
                'classify__C': [1, 10, 100],
                'classify__kernel': ['linear', 'poly', 'rbf', 'sigmoid']
                }
grid13 = GridSearchCV(pipe13, hyperparams13, cv=10, scoring='f1_macro').fit(X_m, y_m)

# %%
results13 = grid13.cv_results_
df13 = pd.DataFrame(results13['params'])
df13['score'] = results13['mean_test_score']
M13 = df13['score'].max()
mask13 = df13['score'] >= M13 * 0.95
df13[mask13].sort_values(by='score', ascending=False)
# Out:
#      classify__C classify__kernel  dim_reduce__n_components     score
# 228          100              rbf                        19  0.876844
# 226          100              rbf                        17  0.876297
# 230          100              rbf                        21  0.875782
# 229          100              rbf                        20  0.875782
# 142           10              rbf                        17  0.875714
# 227          100              rbf                        18  0.875172
# 143           10              rbf                        18  0.874656
# 223          100              rbf                        14  0.872897
# 224          100              rbf                        15  0.872181
# 222          100              rbf                        13  0.871267
# 144           10              rbf                        19  0.870330
# 146           10              rbf                        21  0.870109
# 145           10              rbf                        20  0.870109
# 225          100              rbf                        16  0.869475
# 141           10              rbf                        16  0.866986
# 140           10              rbf                        15  0.862517
# 138           10              rbf                        13  0.860628
# 220          100              rbf                        11  0.860575
# 137           10              rbf                        12  0.860560
# 124           10             poly                        20  0.859780
# 125           10             poly                        21  0.859780
# 123           10             poly                        19  0.859780
# 221          100              rbf                        12  0.859116
# 120           10             poly                        16  0.858583
# 139           10              rbf                        14  0.858041
# 122           10             poly                        18  0.853841
# 121           10             poly                        17  0.852156
# 118           10             poly                        14  0.851949
# 201          100             poly                        13  0.850178
# 208          100             poly                        20  0.849019
# 209          100             poly                        21  0.849019
# 207          100             poly                        19  0.846993
# 202          100             poly                        14  0.846391
# 119           10             poly                        15  0.845932
# 206          100             poly                        18  0.843812
# 204          100             poly                        16  0.843748
# 205          100             poly                        17  0.841970
# 203          100             poly                        15  0.840662
# 200          100             poly                        12  0.839590
# 117           10             poly                        13  0.838962
# 62             1              rbf                        21  0.838515
# 61             1              rbf                        20  0.838515
# 219          100              rbf                        10  0.837335
# 60             1              rbf                        19  0.836380
# 59             1              rbf                        18  0.835240
# 116           10             poly                        12  0.834240
# 58             1              rbf                        17  0.834091

# %%
pipe14 = Pipeline([('scale', MinMaxScaler()),
                  ('dim_reduce', PCA()),
                  ('classify', SVC())
                  ])
hyperparams14 = {'dim_reduce__n_components': np.arange(1, d+1),
                'classify__C': [1, 10, 100],
                'classify__kernel': ['linear', 'poly', 'rbf', 'sigmoid']
                }
grid14 = GridSearchCV(pipe14, hyperparams14, cv=10, scoring='f1_macro').fit(X_m, y_m)

# %%
results14 = grid14.cv_results_
df14 = pd.DataFrame(results14['params'])
df14['score'] = results14['mean_test_score']
M14 = df14['score'].max()
mask14 = df14['score'] >= M14 * 0.95
df14[mask14].sort_values(by='score', ascending=False)
# Out:
#      classify__C classify__kernel  dim_reduce__n_components     score
# 136           10              rbf                        11  0.875746
# 135           10              rbf                        10  0.875043
# 222          100              rbf                        13  0.872971
# 141           10              rbf                        16  0.872654
# 221          100              rbf                        12  0.872648
# ..           ...              ...                       ...       ...
# 57             1              rbf                        16  0.833929
# 54             1              rbf                        13  0.833482
# 60             1              rbf                        19  0.832670
# 58             1              rbf                        17  0.832554
# 59             1              rbf                        18  0.832004
#
# [67 rows x 4 columns]

# %%
pipe15 = Pipeline([('scale', RobustScaler()),
                  ('dim_reduce', PCA()),
                  ('classify', SVC())
                  ])
hyperparams15 = {'dim_reduce__n_components': np.arange(1, d+1),
                'classify__C': [1, 10, 100],
                'classify__kernel': ['linear', 'poly', 'rbf', 'sigmoid']
                }
grid15 = GridSearchCV(pipe15, hyperparams15, cv=10, scoring='f1_macro').fit(X_m, y_m)

# %%
results15 = grid15.cv_results_
df15 = pd.DataFrame(results15['params'])
df15['score'] = results15['mean_test_score']
M15 = df15['score'].max()
mask15 = df15['score'] >= M15 * 0.95
df15[mask15].sort_values(by='score', ascending=False)
# Out:
#      classify__C classify__kernel  dim_reduce__n_components     score
# 230          100              rbf                        21  0.834287
# 229          100              rbf                        20  0.834287
# 225          100              rbf                        16  0.833796
# 228          100              rbf                        19  0.833313
# 222          100              rbf                        13  0.832677
# 226          100              rbf                        17  0.832495
# 221          100              rbf                        12  0.831757
# 223          100              rbf                        14  0.831523
# 227          100              rbf                        18  0.831144
# 220          100              rbf                        11  0.830875
# 224          100              rbf                        15  0.830555
# 219          100              rbf                        10  0.826596
# 98            10           linear                        15  0.817173
# 99            10           linear                        16  0.816530
# 218          100              rbf                         9  0.813832
# 183          100           linear                        16  0.813152
# 182          100           linear                        15  0.811683
# 12             1           linear                        13  0.810410
# 100           10           linear                        17  0.809200
# 15             1           linear                        16  0.808921
# 184          100           linear                        17  0.808729
# 217          100              rbf                         8  0.808697
# 13             1           linear                        14  0.808345
# 97            10           linear                        14  0.807785
# 14             1           linear                        15  0.807175
# 181          100           linear                        14  0.805093
# 96            10           linear                        13  0.803611
# 101           10           linear                        18  0.803055
# 140           10              rbf                        15  0.802107
# 143           10              rbf                        18  0.801905
# 104           10           linear                        21  0.801875
# 103           10           linear                        20  0.801875
# 141           10              rbf                        16  0.801775
# 180          100           linear                        13  0.801762
# 16             1           linear                        17  0.801129
# 102           10           linear                        19  0.800542
# 179          100           linear                        12  0.799900
# 95            10           linear                        12  0.799718
# 146           10              rbf                        21  0.799380
# 145           10              rbf                        20  0.799380
# 144           10              rbf                        19  0.799380
# 185          100           linear                        18  0.799372
# 11             1           linear                        12  0.799193
# 17             1           linear                        18  0.798394
# 139           10              rbf                        14  0.797853
# 142           10              rbf                        17  0.797627
# 94            10           linear                        11  0.797014
# 20             1           linear                        21  0.796938
# 19             1           linear                        20  0.796938
# 18             1           linear                        19  0.796938
# 186          100           linear                        19  0.796879
# 188          100           linear                        21  0.796266
# 187          100           linear                        20  0.796266
# 138           10              rbf                        13  0.795657
# 8              1           linear                         9  0.794519
